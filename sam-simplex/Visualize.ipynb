# %%
import sys
path = "/nasbrain/f21lin/simplex_frederic/fredVenv/lib/python3.10/site-packages"
if path not in sys.path: sys.path.append(path)
import torch
import os
from config import config
import cv2
import matplotlib.pyplot as plt

# %%
runs_path = config.runs_path
crops_path = config.crops_path
runs = os.listdir(runs_path)

# %%
run_path = os.path.join(runs_path,runs[2])
crop_path = os.path.join(crops_path,runs[2])
crops = os.listdir(crop_path)
images = os.listdir(run_path)

# %%
image = cv2.imread(os.path.join(run_path,images[0]))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
os.path.join(crop_path,crops[6])
# Out:
# '/nasbrain/f21lin/crops/run_2/n0320774300000266-7.jpg'

# %%
crop = cv2.imread(os.path.join(crop_path,crops[0]))
crop = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
plt.imshow(crop)
plt.show()
